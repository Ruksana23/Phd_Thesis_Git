# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import xarray as xr
from scipy import stats
import os
import glob
from pathlib import Path  
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy.signal import correlate 
# import warnings
# warnings.filterwarnings('ignore')
# import statsmodels.api as sm
import natsort 
import datetime as dt
import scipy
import utide
from astropy.io import ascii

# %%
import sys
import time
import logging
import configparser
import json
import pandas as pd
import numpy as np
import configuration.constants as c
import utils.iofilehandler as iofilehandler
import utils.dataframe as dataframe
import modules.qc as qc
import modules.filterhandler as filt
import modules.tidesurge as surge
import modules.interpolation as inter

# %%
# %load selene.py
'''
selene
Created on 5 jun. 2018
@author: AMG
'''
import sys
import time
import logging
import configparser
import json
import pandas as pd
import numpy as np
import configuration.constants as c
import utils.iofilehandler as iofilehandler
import utils.dataframe as dataframe
import modules.qc as qc
import modules.filterhandler as filt
import modules.tidesurge as surge
import modules.interpolation as inter
stationid = sys.argv[1]
initime = time.time()
#log
extralogatt = {'station':stationid}
logger = logging.getLogger('selene')
fh = logging.FileHandler(c.logfile)
fh.setFormatter(logging.Formatter('%(asctime)s %(station)s %(levelname)s %(message)s'))
logger.addHandler(fh) 
logger.setLevel(logging.INFO)
logger = logging.LoggerAdapter(logger, extralogatt)
#config
t = time.time()
logger.info('SELENE application >> started!')
config = configparser.ConfigParser()
config.read(c.configini)
logger.info('Config file: ' + c.configini + ' read!')
with open(c.stationsfile) as f:
    stations = json.load(f)
logger.info('Stations json file: ' + c.stationsfile + ' loaded!')
logger.debug('TIME to read config and json files: ' + str(time.time() - t) + ' seconds')
if stationid not in stations:
    logger.error('Station id ' + stationid + ' not set in stations.json. SELENE terminated!')
    sys.exit()
try:
    t = time.time()
    #ORIGINAL SAMPLING SEA LEVEL
    originaldf = iofilehandler.txtfile2dataframe(stations[stationid]['seriesfile'],stations[stationid]['seriesseparator'],list(map(int,stations[stationid]['seriesdatecolumns'].split(','))),stations[stationid]['seriesdateformat'],stations[stationid]['seriesvaluecolumn'],stations[stationid]['seriesqccolumn'],logger)
    if originaldf.empty:
        logger.info('Empty file for station ' + stationid)
        sys.exit()
    foremanstartdate = pd.to_datetime(originaldf.index.values[0])
    foremanenddate = pd.to_datetime(originaldf.index.values[-1])
    logger.debug('TIME to create dataframe from series file: ' + str(time.time() - t) + ' seconds')
    t = time.time()
    if originaldf[(originaldf.quality != 4) & (originaldf.quality != 9)].empty == True:
        logger.info('All data in station ' + stationid + ' is wrong or null (qc = 4 or qc = 9)')
        sys.exit()
    #ORIGINAL SAMPLING DATA WITH FLAGS
    originaldfwithflags = qc.qc(originaldf,stations[stationid]['qc_level_nsigma'],stations[stationid]['qc_level_winsize'],stations[stationid]['qc_level_splinedegree'],stations[stationid]['qc_stucklimit'],stations[stationid]['maxlevel'],stations[stationid]['minlevel'],logger,c)
    logger.info('TIME to check quality - qc module: ' + str(time.time() - t) + ' seconds')
    t = time.time()
    originalmininterval = dataframe.mininterval(originaldf)
    if originalmininterval <= 0:
        originalmininterval = 1
    if stations[stationid]['foremanharmfile']:
        #ORIGINAL SAMPLING INTERPOLATED DATA
        originaldfinterpolated = inter.interpolate(originaldfwithflags,None,originalmininterval,logger,config,c)
        logger.debug('TIME to interpolate to original sampling - interpolation module: ' + str(time.time() - t) + ' seconds')
        t = time.time()
        #ORIGINAL SAMPLING SURGE
        suregeresult = surge.tidesurge('foreman_min_' + stationid + '.in', 'foreman_min_' + stationid + '.out',c.foremanastofile, config['foreman']['harmonicsfolder']+stations[stationid]['foremanharmfile'],foremanstartdate,foremanenddate,c.foremanmode,c.foremanmininterval,stationid,stations[stationid]['name'],stations[stationid]['latitude'],stations[stationid]['longitude'],originaldfinterpolated,logger,config)
        tidesurgedf = suregeresult[0]
        foremanpredictionmin = suregeresult [1]
        logger.debug('TIME to calculate tide surge - tidesurge module: ' + str(time.time() - t) + ' seconds')
        t = time.time()
        #ORIGINAL SAMPLING SURGE WITH FLAGS    
        tidesurgedfnans = tidesurgedf[np.isnan(tidesurgedf.data)]  # flag nones
        if not tidesurgedfnans.empty:
            for ix in tidesurgedfnans.index.values:
                originaldfwithflags.loc[ix, 'quality'] = c.badqc
        tidesurgedfnonans = tidesurgedf.dropna(subset=['data'])  # clean none/empty values to apply quality control procedure
        tidesurgedfwithflags = qc.qc(tidesurgedfnonans,stations[stationid]['qc_surge_nsigma'],stations[stationid]['qc_surge_winsize'],stations[stationid]['qc_surge_splinedegree'],stations[stationid]['qc_stucklimit'],stations[stationid]['maxsurge'],stations[stationid]['minsurge'],logger,c)
        logger.info('TIME to check quality in surge - qc module: ' + str(time.time() - t) + ' seconds')
        t = time.time()
        #Apply flags detected in surge quality control to original series
        tidesurgebadflags = tidesurgedfwithflags[tidesurgedfwithflags.quality == c.badqc]
        if not tidesurgebadflags.empty:
            for ix in tidesurgebadflags.index.values:
                originaldfwithflags.loc[ix,'quality'] = c.badqc
        logger.debug('TIME to apply surge bad data flag to original series: ' + str(time.time() - t) + ' seconds')
        t = time.time()
    dataframe.save(originaldfwithflags.fillna('None'),config['general']['outputfolder']+stationid+'_original_sampling_flags.out')
    #5-MIN INTERPOLATED DATA
    fivemindfinterpolated = inter.interpolate(originaldfwithflags,5,originalmininterval,logger,config,c)
    logger.debug('TIME to interpolate to 5min sampling - interpolation module: ' + str(time.time() - t) + ' seconds')
    t = time.time()
    dataframe.save(fivemindfinterpolated.fillna('None'),config['general']['outputfolder']+stationid+'_5min_interpolated.out')
    #HOURLY LEVEL FILTER VALUES
    hourlyfiltered = filt.filt('pugh',fivemindfinterpolated,5,logger,config,c)
    logger.info('TIME to filter to hourly values - filterhandler module: ' + str(time.time() - t) + ' seconds')
    t = time.time()
    dataframe.save(hourlyfiltered.fillna('None'),config['general']['outputfolder']+stationid+'_hourly_slev.out')
    if stations[stationid]['foremanharmfile']:
        #HOURLY METEOROLOGICAL SURGE
        surgeresult = surge.tidesurge('foreman_hour_' + stationid + '.in', 'foreman_hour_' + stationid + '.out',c.foremanastofile,config['foreman']['harmonicsfolder']+stations[stationid]['foremanharmfile'],foremanstartdate,foremanenddate,c.foremanmode,c.foremanhourlyinterval,stationid,stations[stationid]['name'],stations[stationid]['latitude'],stations[stationid]['longitude'],hourlyfiltered,logger,config)
        hourlytidesurgedf = surgeresult[0]
        foremanpredictionhour = surgeresult[1]
        logger.debug('TIME to calculate hourly tide surge - tidesurge module: ' + str(time.time() - t) + ' seconds')
        t = time.time()
        dataframe.save(foremanpredictionhour.fillna('None'),config['general']['outputfolder']+stationid+'_hourly_prediction.out')
        dataframe.save(hourlytidesurgedf.fillna('None'),config['general']['outputfolder']+stationid+'_hourly_surge.out')
except Exception as e:
    logger.error('Error processing station: ' + stationid)
    logger.error(sys.exc_info())
logger.info('Elapsed time... ' + str(time.time() - initime) + ' seconds')

# %%
df = pd.read_csv("datafiles/Readme.txt", delimiter=r"\s+")
# df

# %%
sub_files = os.listdir("datafiles")
sub_files=natsort.natsorted(sub_files,reverse=False)
year_wise_data=[]
stations=[]
lat_lon=[]
for j in sub_files:
    if j.endswith('.data'):
        year_wise_data.append(j)
        name=j[:-5]
        st=j[2:-10]
        lat_lon.append(st)
        stations.append(name)
# year_wise_data
stations
# Out:
# ['m_AdaniHazira_2015',
#  'm_AdaniHazira_2016',
#  'm_AdaniHazira_2017',
#  'm_AdaniHazira_2018',
#  'm_AdaniHazira_2019',
#  'm_AdaniHazira_2020',
#  'm_AdaniHazira_2021',
#  'm_AdaniHazira_2022']

# %%
col_names =  ["Id","Date","Time","Sl","Flag"]
# st = pd.read_csv("datafiles/"+year_wise_data[0], names=col_names)
# sl = [np.nan if x == -99999999.0 else x for x in st.Sl]
# std_sl=np.nanstd(sl)
# std_sl

# %%
# val = df.loc[df.Station==lat_lon[0], 'Latitude'].values[0]
# val

# %%
for i in range(len(year_wise_data)):
    lon = df.loc[df.Station==lat_lon[i], 'Longitude'].values[0]
    lat = df.loc[df.Station==lat_lon[i], 'Latitude'].values[0]
    st = pd.read_csv("datafiles/"+year_wise_data[i], names=col_names)
    sl = [np.nan if x == -99999999.0 else x for x in st.Sl]
    std_sl=np.nanstd(sl)
    nm=stations[i]
    print('"{}":'.format(stations[i])+' {\n'
          +'        "foremanharmfile": "",\n'
          +'        "latitude":'+'{},\n'.format(lon)
          +'        "longitude":'+'{},\n'.format(lat)
          +'        "name":"'+'{}'.format(nm)+'",\n'
          +'        "maxlevel": 7150,\n'
          +'        "minlevel": -7150,\n'
          # +'        "maxlevel":'+'{},\n'.format(4*std_sl)
          # +'        "minlevel":'+'{},\n'.format(-4*std_sl)
          +'        "qc_level_nsigma": 4,\n'
          +'        "qc_level_splinedegree": 2,\n'
          +'        "qc_level_winsize": 200,\n'
          +'        "qc_stucklimit": 10,\n'
          +'        "qc_surge_nsigma": 5,\n'
          +'        "qc_surge_splinedegree": 3,\n'
          +'        "qc_surge_winsize": 500,\n'
          +'        "seriesdatecolumns": "1,2",\n'
          +'        "seriesdateformat": "%Y%m%d%H%M%S",\n'
          +'        "seriesfile": "datafiles/'+'{}",\n'.format(year_wise_data[i])
          +'        "seriesqccolumn": 4,\n'
          +'        "seriesseparator": ",",\n'
          +'        "seriesvaluecolumn": 3,\n'
          +'        "shortname":"'+'{}'.format(nm)+'"\n'
          +'        },')
#add/modify this text to station.json file content
# Out:
# "m_AdaniHazira_2015": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2015",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2015.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2015"
#         },
# "m_AdaniHazira_2016": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2016",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2016.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2016"
#         },
# "m_AdaniHazira_2017": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2017",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2017.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2017"
#         },
# "m_AdaniHazira_2018": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2018",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2018.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2018"
#         },
# "m_AdaniHazira_2019": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2019",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2019.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2019"
#         },
# "m_AdaniHazira_2020": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2020",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2020.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2020"
#         },
# "m_AdaniHazira_2021": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2021",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2021.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2021"
#         },
# "m_AdaniHazira_2022": {
#         "foremanharmfile": "",
#         "latitude":72.616,
#         "longitude":21.1,
#         "name":"m_AdaniHazira_2022",
#         "maxlevel": 7150,
#         "minlevel": -7150,
#         "qc_level_nsigma": 4,
#         "qc_level_splinedegree": 2,
#         "qc_level_winsize": 200,
#         "qc_stucklimit": 10,
#         "qc_surge_nsigma": 5,
#         "qc_surge_splinedegree": 3,
#         "qc_surge_winsize": 500,
#         "seriesdatecolumns": "1,2",
#         "seriesdateformat": "%Y%m%d%H%M%S",
#         "seriesfile": "datafiles/m_AdaniHazira_2022.data",
#         "seriesqccolumn": 4,
#         "seriesseparator": ",",
#         "seriesvaluecolumn": 3,
#         "shortname":"m_AdaniHazira_2022"
#         },

# %%
for i in range(len(year_wise_data)):
    x=stations[i].replace("'", "")
    print(x)
    # %run selene.py x
# Out:
# m_AdaniHazira_2015
# m_AdaniHazira_2016
# m_AdaniHazira_2017
# m_AdaniHazira_2018
# m_AdaniHazira_2019
# m_AdaniHazira_2020
# m_AdaniHazira_2021
# m_AdaniHazira_2022

# %%
# %run selene.py m_AdaniHazira_2022 #run only once for each station
# Out:
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   targetdf = targetdf.append(resampleandinterpolate(df[ini:end],mininterval,c))
# /home/ruksana/Desktop/work_updates/SELENE-master/modules/interpolation.py:46: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   targetdf = targetdf.drop('quality', 1)

# %%
# %load selenevis.py

# %%
# %run selenevis.py -files outputs/3108_original_sampling_flags.out

# %%
# %run selenevis.py -files outputs/3108_hourly_slev.out

# %%
# %run selenevis.py -files outputs/3108_5min_interpolated.out

# %%
output=[]
sub_files=os.listdir("outputs")
sub_files=natsort.natsorted(sub_files,reverse=False)
res=pd.DataFrame()
per=[]
yr=[]
for f in sub_files:
    time_per=[]
    # f = open(file)
    # for line in f:
    if '5min' in f:
        nm=f[14:18]
        yr.append(int(nm))
        # print(f)
        col_names =  ["Time","Sl"]
        df = pd.read_csv("outputs/"+f, names=col_names, delimiter=r"\s+")
        # df[["date","time"]] = df["Time"].str.split(" ", expand = True)
        df['Sl'].replace("None",np.nan , inplace=True)
        df['Sl'].astype(float)
        df["Time"]=pd.to_datetime(df["Time"])
        df3=df.set_index(['Time'])
        df4 = df3.resample('1Min').sum()
        df4['Sl']=df4['Sl'].astype(float)
        df4.Sl = df4.Sl.replace(0,np.nan)
        df4.interpolate()
        obs=df4
        obs = obs.resample('H').mean() 
        obs["anomaly"] = obs["Sl"] - obs["Sl"].mean()
        n=obs["anomaly"].isna().sum()
        per.append((n*100)/len(obs))
        if len(obs)>4000:
            for j in range(len(obs)): 
                k=obs.index.year[j]+(j/len(obs))
                time_per.append(k)
        else:
            for l in range(len(obs)): 
                g=5722-(len(obs))
                m=obs.index.year[l]+((l+g)/5722)
                time_per.append(m)
        obs["time_per"] = time_per
        res = pd.concat([res, obs], axis=0)

# %%
res
# Out:
#                               Sl      anomaly     time_per
# Time
# 2015-12-08 00:00:00  3673.333333  -485.786038  2015.899336
# 2015-12-08 01:00:00  3122.500000 -1036.619371  2015.899511
# 2015-12-08 02:00:00  2862.500000 -1296.619371  2015.899685
# 2015-12-08 03:00:00  3080.833333 -1078.286038  2015.899860
# 2015-12-08 04:00:00  3765.833333  -393.286038  2015.900035
# ...                          ...          ...          ...
# 2022-08-27 05:00:00  1923.500000 -2237.707171  2022.999126
# 2022-08-27 06:00:00  3341.000000  -820.207171  2022.999301
# 2022-08-27 07:00:00  4774.166667   612.959496  2022.999476
# 2022-08-27 08:00:00  5987.500000  1826.292829  2022.999650
# 2022-08-27 09:00:00  6482.000000  2320.792829  2022.999825
#
# [58903 rows x 3 columns]

# %%
# creating data_gap _file for heat map
per_df=pd.DataFrame({"year":yr,"percentage":per})
yr_array=np.arange(2010,2023,1)
val=[]
name=[]
for i in yr_array:
    name.append(lat_lon[0])
    if i in yr:
        value=(per_df.loc[per_df['year'] == i,'percentage']).values
        v=value[0]
        val.append(round(v,2))
    else:
        val.append(round(100,2))
        # res = pd.concat([res, obs], axis=0)
data_gap=pd.DataFrame({"place":name,"year":yr_array,"percentage":val})
# data_gap
# data_gap.to_csv("datafiles/"+lat_lon[0]+"_output_data_gap.csv")#########################################################################################

# %%
res
# Out:
#                               Sl      anomaly     time_per
# Time
# 2015-12-08 00:00:00  3673.333333  -485.786038  2015.899336
# 2015-12-08 01:00:00  3122.500000 -1036.619371  2015.899511
# 2015-12-08 02:00:00  2862.500000 -1296.619371  2015.899685
# 2015-12-08 03:00:00  3080.833333 -1078.286038  2015.899860
# 2015-12-08 04:00:00  3765.833333  -393.286038  2015.900035
# ...                          ...          ...          ...
# 2022-08-27 05:00:00  1923.500000 -2237.707171  2022.999126
# 2022-08-27 06:00:00  3341.000000  -820.207171  2022.999301
# 2022-08-27 07:00:00  4774.166667   612.959496  2022.999476
# 2022-08-27 08:00:00  5987.500000  1826.292829  2022.999650
# 2022-08-27 09:00:00  6482.000000  2320.792829  2022.999825
#
# [58903 rows x 3 columns]

# %%
coef = utide.solve(
    res.index,
    res["anomaly"],
    lat=21.1,
    method="ols",
    conf_int="MC",
    verbose=False,
    )
tide = utide.reconstruct(res.index, coef, verbose=False)
t=res.index.values
y=res.anomaly - tide.h



fig, (ax0, ax1, ax2) = plt.subplots(figsize=(17, 5), nrows=3,sharex=True,)
# st = fig.suptitle(lat_lon[0] ,fontsize="x-large")
ax0.plot(t, res.anomaly, label="Observations", color="C0")
ax1.plot(t, tide.h, label="Prediction", color="C1")
ax2.plot(t, y, label="Residual", color="C2")
fig.legend(ncol=3, loc="upper right",bbox_to_anchor=(.9, 1));
st.set_y(0.98)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4583/546889390.py in <module>
#      19 ax2.plot(t, y, label="Residual", color="C2")
#      20 fig.legend(ncol=3, loc="upper right",bbox_to_anchor=(.9, 1));
# ---> 21 st.set_y(0.98)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'set_y'

# %%
U_Tide_output_file= pd.DataFrame({"time":res.index,"sl_anomaly":y})
U_Tide_output_file1=U_Tide_output_file.drop(['time'], axis=1)
U_Tide_output_file1.to_csv("datafiles/"+lat_lon[0]+"_output_UTide.csv")#########################################################################################
#collect all final_res files and keep it in seperatefile/folder

# %%
amelia_file= pd.DataFrame({"time":res.time_per,"sl_anomaly":y})
amelia_file1=amelia_file.set_index(['time'])

amelia_file1.plot(figsize=(17, 2))
amelia_file1.to_csv("datafiles/"+lat_lon[0]+"_output_amelia.csv")#########################################################################################

# %%
y1= pd.DataFrame(y)
y1.to_csv("datafiles/"+lat_lon[0]+"_output.csv")#########################################################################################

# %%
yd= pd.DataFrame(y.resample('1D').mean())
t=yd.index.values
yd
# Out:
#                anomaly
# Time
# 2015-12-08   68.868217
# 2015-12-09  114.255231
# 2015-12-10  152.972948
# 2015-12-11   68.337032
# 2015-12-12   18.506461
# ...                ...
# 2022-08-23 -214.058721
# 2022-08-24 -254.466865
# 2022-08-25 -252.144336
# 2022-08-26 -281.375893
# 2022-08-27 -384.302021
#
# [2455 rows x 1 columns]

# %%
import pymannkendall as mk
result =mk.original_test(yd)

# %%
sl=yd.anomaly

plt.plot(t,sl)
plt.xlim()
plt.ylim()
plt.xlabel(result.trend)
# plt.xlabel(result)


c=result.intercept
m=result.slope
length=len(sl)
a = np.linspace(0,length,length).astype('int')
y1=(m*a)+c
plt.plot(t,y1)
plt.ylabel('Sl in mm')
plt.grid(True)
# plt.title(tide.name)
    # plt.savefig(tide.name+".jpeg",dpi=300, bbox_inches='tight')

# plt.show()

# %%
#processing amelia results
sub_files=os.listdir("datafiles")
sub_files=natsort.natsorted(sub_files,reverse=False)
loc=[]
for j in sub_files:
    if j.startswith(lat_lon[0]+'_output_amelia-imp'):
        name=j
        loc.append(name)
print(len(loc))
# year_wise_data
# Out:
# 5

# %%
a0=pd.read_csv("datafiles/"+loc[0])
a1=pd.read_csv("datafiles/"+loc[1])
a2=pd.read_csv("datafiles/"+loc[2])
a3=pd.read_csv("datafiles/"+loc[3])
a4=pd.read_csv("datafiles/"+loc[4])


sl0=a0.sl_anomaly
sl1=a1.sl_anomaly
sl2=a2.sl_anomaly
sl3=a3.sl_anomaly
sl4=a4.sl_anomaly

avg_sl = (sl0+sl1+sl2+sl3+sl4) / (len(loc))
avg_sl
# Out:
# 0        -14.121733
# 1         35.600945
# 2         59.622895
# 3         63.117917
# 4        111.970040
#             ...
# 58898   -388.660205
# 58899   -400.210026
# 58900   -462.128923
# 58901   -373.461656
# 58902   -505.174756
# Name: sl_anomaly, Length: 58903, dtype: float64

# %%
final_res=pd.DataFrame({"Time":res.index,"Anomaly":avg_sl})
final_res
# Out:
#                      Time     Anomaly
# 0     2015-12-08 00:00:00  -14.121733
# 1     2015-12-08 01:00:00   35.600945
# 2     2015-12-08 02:00:00   59.622895
# 3     2015-12-08 03:00:00   63.117917
# 4     2015-12-08 04:00:00  111.970040
# ...                   ...         ...
# 58898 2022-08-27 05:00:00 -388.660205
# 58899 2022-08-27 06:00:00 -400.210026
# 58900 2022-08-27 07:00:00 -462.128923
# 58901 2022-08-27 08:00:00 -373.461656
# 58902 2022-08-27 09:00:00 -505.174756
#
# [58903 rows x 2 columns]

# %%
# plt.plot(final_res.Time,final_res.Anomaly)

# %%
final_res1 = final_res.set_index(['Time'])
final_res1.to_csv("datafiles/"+lat_lon[0]+"_output_final_res.csv")#########################################################################################
#collect all final_res files and keep it in seperatefile/folder
#do spectrum and coherence and many more on that only

# %%
final_res2=final_res1.to_xarray()
final_res2
# Out:
# <xarray.Dataset>
# Dimensions:  (Time: 58903)
# Coordinates:
#   * Time     (Time) datetime64[ns] 2015-12-08 ... 2022-08-27T09:00:00
# Data variables:
#     Anomaly  (Time) float64 -14.12 35.6 59.62 63.12 ... -462.1 -373.5 -505.2

# %%
final_res2.to_netcdf("datafiles/"+lat_lon[0]+"_output.nc")#########################################################################################
#prepare the spectrum file in ncl

# %%
data = xr.open_dataset("datafiles/"+"fft_ci95_hrly_adani_output.nc")
data
# Out:
# <xarray.Dataset>
# Dimensions:   (ncl0: 29451, ncl1: 29451, ncl2: 29451)
# Dimensions without coordinates: ncl0, ncl1, ncl2
# Data variables:
#     spectrum  (ncl0) float64 ...
#     ci_95     (ncl1) float64 ...
#     periodn   (ncl2) float64 ...

# %%
data1 = xr.open_dataset("datafiles/"+"fft_ci99_hrly_adani_output.nc")
data1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     208             try:
# --> 209                 file = self._cache[self._key]
#     210             except KeyError:
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      54         with self._lock:
# ---> 55             value = self._cache[key]
#      56             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/ruksana/Desktop/work_updates/SELENE-master/datafiles/fft_ci99_hrly_adani.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '1e845aaa-0994-46dd-bfb2-64b1078c96e1']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4583/2467284805.py in <module>
# ----> 1 data1 = xr.open_dataset("datafiles/"+"fft_ci99_hrly_adani.nc")
#       2 data1
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     537
#     538     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 539     backend_ds = backend.open_dataset(
#     540         filename_or_obj,
#     541         drop_variables=drop_variables,
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     570
#     571         filename_or_obj = _normalize_path(filename_or_obj)
# --> 572         store = NetCDF4DataStore.open(
#     573             filename_or_obj,
#     574             mode=mode,
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     374             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     375         )
# --> 376         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     377
#     378     def _acquire(self, needs_lock=True):
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     321         self._group = group
#     322         self._mode = mode
# --> 323         self.format = self.ds.data_model
#     324         self._filename = self.ds.filepath()
#     325         self.is_remote = is_remote_uri(self._filename)
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     383     @property
#     384     def ds(self):
# --> 385         return self._acquire()
#     386
#     387     def open_store_variable(self, name, var):
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     377
#     378     def _acquire(self, needs_lock=True):
# --> 379         with self._manager.acquire_context(needs_lock) as root:
#     380             ds = _nc4_require_group(root, self._group, self._mode)
#     381         return ds
#
# ~/anaconda3/lib/python3.9/contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     195     def acquire_context(self, needs_lock=True):
#     196         """Context manager for acquiring a file."""
# --> 197         file, cached = self._acquire_with_cache_info(needs_lock)
#     198         try:
#     199             yield file
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     213                     kwargs = kwargs.copy()
#     214                     kwargs["mode"] = self._mode
# --> 215                 file = self._opener(*self._args, **kwargs)
#     216                 if self._mode == "w":
#     217                     # ensure file doesn't get overridden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/home/ruksana/Desktop/work_updates/SELENE-master/datafiles/fft_ci99_hrly_adani.nc'

# %%
period=data.periodn/24
spectrum=data.spectrum
sig=data.ci_95

# %%
period1=data1.periodn/24
spectrum1=data1.spectrum
sig1=data1.ci_95

# %%
plt.plot(period1,spectrum1)
plt.plot(period1,sig1)
plt.xlim(0,10)
plt.title("sig_99_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_99_fft_spectrum')

# %%
plt.plot(period,spectrum)
plt.plot(period,sig)
plt.xlim(0,250)
plt.title("sig_95_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_95_fft_spectrum')

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Create a sample dataset
# data = data_gap
# data = data.pivot("place","year","percentage")

# data
# Out:
# year          2010   2011   2012   2013   2014   2015  2016  2017   2018  \
# place
# AdaniHazira  100.0  100.0  100.0  100.0  100.0  38.89  2.37  7.17  22.65
#
# year          2019   2020   2021  2022
# place
# AdaniHazira  18.95  30.85  20.08  8.63

# %%
# # Create heatmap using Seaborn library 
# plt.figure(figsize = (16,8))
# sns.heatmap(data, annot=True, fmt=".1f", cmap=sns.cubehelix_palette(as_cmap=True), linewidths=0)

# # Set title and axis labels
# plt.title("Data gap% yearwise")
# plt.xlabel("Year")
# plt.ylabel("Stations")
# plt.yticks(rotation=0)
# plt.xticks(rotation=45)

# # Show the plot
# plt.show()
