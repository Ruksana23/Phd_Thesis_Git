# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import xarray as xr
from scipy import stats
import os
import glob
from pathlib import Path  
from sklearn.metrics import mean_squared_error
from math import sqrt
from scipy.signal import correlate 
# import warnings
# warnings.filterwarnings('ignore')
# import statsmodels.api as sm
import natsort 
import datetime
import scipy
import utide

# %%
data = xr.open_dataset("fft_ci90_hrly.nc")
data
# Out:
# <xarray.Dataset>
# Dimensions:   (ncl0: 4392, ncl1: 4392, ncl2: 4392)
# Dimensions without coordinates: ncl0, ncl1, ncl2
# Data variables:
#     spectrum  (ncl0) float64 ...
#     ci_90     (ncl1) float64 ...
#     periodn   (ncl2) float64 ...

# %%
period1=data.periodn/24
spectrum1=data.spectrum
sig1=data.ci_90

# %%
plt.plot(period,spectrum)
plt.plot(period,sig)
plt.xlim(0,150)
plt.title("sig_90_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_90_fft_spectrum')

# %%
data = xr.open_dataset("fft_ci95_hrly.nc")
data
# Out:
# <xarray.Dataset>
# Dimensions:   (ncl0: 4392, ncl1: 4392, ncl2: 4392)
# Dimensions without coordinates: ncl0, ncl1, ncl2
# Data variables:
#     spectrum  (ncl0) float64 ...
#     ci_95     (ncl1) float64 ...
#     periodn   (ncl2) float64 ...

# %%
period2=data.periodn/24
spectrum2=data.spectrum
sig2=data.ci_95
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_26269/1631124058.py in <module>
# ----> 1 period2=data.periodn*24
#       2 spectrum2=data.spectrum
#       3 sig2=data.ci_95
#
# NameError: name 'data' is not defined

# %%
plt.plot(period1,spectrum1)
plt.plot(period1,sig1)
plt.plot(period1,sig2)

plt.xlim()
plt.title("sig_90&95_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_90&95_fft_spectrum')

# %%
plt.plot(period1,spectrum1)
plt.plot(period1,sig1)
plt.plot(period1,sig2)

plt.xlim(0,250)
plt.title("sig_90&95_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_90&95_fft_spectrum')

# %%
plt.plot(period1,spectrum1)
plt.plot(period1,sig1)
plt.plot(period1,sig2)

plt.xlim(0,150)
plt.title("sig_90&95_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_90&95_fft_spectrum')

# %%
plt.plot(period1,spectrum1)
plt.plot(period1,sig1)
plt.plot(period1,sig2)

plt.xlim(0,58)
plt.title("sig_90&95_fft_spectrum" ,fontsize="x-large")
# Out:
# Text(0.5, 1.0, 'sig_90&95_fft_spectrum')
